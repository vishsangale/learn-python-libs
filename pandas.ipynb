# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 19.2.3, however version 21.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd

df = pd.read_csv("data/survey_results_public.csv")

# %%
df.size # total size of the dataframe
# Out:
# 3932121

# %%
df.shape # shape of dataframe
# Out:
# (64461, 61)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
df.columns # list columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
len(df.columns)
# Out:
# 61

# %%
len(df)
# Out:
# 64461

# %%
# iterate over columns
for column in df.columns:
    print(column, end="\t")
# Out:
# Respondent	MainBranch	Hobbyist	Age	Age1stCode	CompFreq	CompTotal	ConvertedComp	Country	CurrencyDesc	CurrencySymbol	DatabaseDesireNextYear	DatabaseWorkedWith	DevType	EdLevel	Employment	Ethnicity	Gender	JobFactors	JobSat	JobSeek	LanguageDesireNextYear	LanguageWorkedWith	MiscTechDesireNextYear	MiscTechWorkedWith	NEWCollabToolsDesireNextYear	NEWCollabToolsWorkedWith	NEWDevOps	NEWDevOpsImpt	NEWEdImpt	NEWJobHunt	NEWJobHuntResearch	NEWLearn	NEWOffTopic	NEWOnboardGood	NEWOtherComms	NEWOvertime	NEWPurchaseResearch	NEWPurpleLink	NEWSOSites	NEWStuck	OpSys	OrgSize	PlatformDesireNextYear	PlatformWorkedWith	PurchaseWhat	Sexuality	SOAccount	SOComm	SOPartFreq	SOVisitFreq	SurveyEase	SurveyLength	Trans	UndergradMajor	WebframeDesireNextYear	WebframeWorkedWith	WelcomeChange	WorkWeekHrs	YearsCode	YearsCodePro

# %%
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc  ... SurveyEase SurveyLength  \
# 64456            NaN  United States          NaN  ...        NaN          NaN
# 64457            NaN        Morocco          NaN  ...        NaN          NaN
# 64458            NaN       Viet Nam          NaN  ...        NaN          NaN
# 64459            NaN         Poland          NaN  ...        NaN          NaN
# 64460            NaN          Spain          NaN  ...        NaN          NaN
#
# ...

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64451       64104        NaN      Yes  NaN         19      NaN        NaN
# 64452       64236        NaN      Yes  NaN        NaN      NaN        NaN
# 64453       64330        NaN      Yes  NaN          5      NaN        NaN
# 64454       64480        NaN      Yes  NaN         21      NaN        NaN
# 64455       64567        NaN      Yes  NaN        NaN      NaN        NaN
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc  ... SurveyEase SurveyLength  \
# ...

# %%
df["Country"]
# Out:
# 0                   Germany
# 1            United Kingdom
# 2        Russian Federation
# 3                   Albania
# 4             United States
#                 ...
# 64456         United States
# 64457               Morocco
# 64458              Viet Nam
# 64459                Poland
# 64460                 Spain
# Name: Country, Length: 64461, dtype: object

# %%
df["Country"] == "Germany"
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 64456    False
# 64457    False
# 64458    False
# 64459    False
# 64460    False
# Name: Country, Length: 64461, dtype: bool

# %%
df[["Country", "Age1stCode"]]
# Out:
#                   Country Age1stCode
# 0                 Germany         13
# 1          United Kingdom         19
# 2      Russian Federation         15
# 3                 Albania         18
# 4           United States         16
# ...                   ...        ...
# 64456       United States         16
# 64457             Morocco        NaN
# 64458            Viet Nam        NaN
# 64459              Poland        NaN
# 64460               Spain        NaN
#
# [64461 rows x 2 columns]

# %%
df.iloc[0] # access row by integer location
# Out:
# Respondent                                                  1
# MainBranch                     I am a developer by profession
# Hobbyist                                                  Yes
# Age                                                       NaN
# Age1stCode                                                 13
#                                        ...
# WebframeWorkedWith                       ASP.NET;ASP.NET Core
# WelcomeChange         Just as welcome now as I felt last year
# WorkWeekHrs                                              50.0
# YearsCode                                                  36
# YearsCodePro                                               27
# Name: 0, Length: 61, dtype: object

# %%
df.iloc[[0, 2]] # multiple rows
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           1  I am a developer by profession      Yes  NaN         13
# 2           3     I code primarily as a hobby      Yes  NaN         15
#
#   CompFreq  CompTotal  ConvertedComp             Country   CurrencyDesc  ...  \
# 0  Monthly        NaN            NaN             Germany  European Euro  ...
# 2      NaN        NaN            NaN  Russian Federation            NaN  ...
#
#                    SurveyEase           SurveyLength Trans  \
# 0  Neither easy nor difficult  Appropriate in length    No
# 2  Neither easy nor difficult  Appropriate in length   NaN
#
#                                       UndergradMajor WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...           ASP.NET Core
# 2                                                NaN                    NaN
#
#      WebframeWorkedWith                             WelcomeChange WorkWeekHrs  \
# ...

# %%
df.iloc[[0, 2], 1] # access rows and column
# Out:
# 0    I am a developer by profession
# 2       I code primarily as a hobby
# Name: MainBranch, dtype: object

# %%
df.loc[3] # access using labels
# Out:
# Respondent                                                   4
# MainBranch                      I am a developer by profession
# Hobbyist                                                   Yes
# Age                                                       25.0
# Age1stCode                                                  18
#                                         ...
# WebframeWorkedWith                                         NaN
# WelcomeChange         Somewhat less welcome now than last year
# WorkWeekHrs                                               40.0
# YearsCode                                                    7
# YearsCodePro                                                 4
# Name: 3, Length: 61, dtype: object

# %%
df.loc[[3, 2]]
# Out:
#    Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 3           4  I am a developer by profession      Yes  25.0         18
# 2           3     I code primarily as a hobby      Yes   NaN         15
#
#   CompFreq  CompTotal  ConvertedComp             Country  CurrencyDesc  ...  \
# 3      NaN        NaN            NaN             Albania  Albanian lek  ...
# 2      NaN        NaN            NaN  Russian Federation           NaN  ...
#
#                    SurveyEase           SurveyLength Trans  \
# 3                         NaN                    NaN    No
# 2  Neither easy nor difficult  Appropriate in length   NaN
#
#                                       UndergradMajor WebframeDesireNextYear  \
# 3  Computer science, computer engineering, or sof...                    NaN
# 2                                                NaN                    NaN
#
#   WebframeWorkedWith                             WelcomeChange WorkWeekHrs  \
# ...

# %%
df.loc[[3, 2, 25, 34], ["Age", "Country"]]
# Out:
#      Age             Country
# 3   25.0             Albania
# 2    NaN  Russian Federation
# 25   NaN              Canada
# 34  16.0       United States

# %%
df["Hobbyist"].value_counts() # counts values with all the types
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df["Country"].value_counts() # count different countries
# Out:
# 8403

# %%
df["Country"].value_counts()["Canada"] # Count Canadians
# Out:
# 2191

# %%
df.loc[4:9, "Country"] # Slicing rows
# Out:
# 4     United States
# 5           Germany
# 6             India
# 7     United States
# 8           Tunisia
# 9    United Kingdom
# Name: Country, dtype: object

# %%
df.loc[4:9, "Hobbyist":"Country"]
# Out:
#   Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp         Country
# 4      Yes  31.0         16      NaN        NaN            NaN   United States
# 5       No   NaN         14      NaN        NaN            NaN         Germany
# 6      Yes   NaN         18  Monthly        NaN            NaN           India
# 7      Yes  36.0         12   Yearly   116000.0       116000.0   United States
# 8       No  30.0         20      NaN        NaN            NaN         Tunisia
# 9      Yes  22.0         14   Yearly    25000.0        32315.0  United Kingdom

# %%
df.set_index("Age")
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# Age
# NaN            1                     I am a developer by profession      Yes
# NaN            2                     I am a developer by profession       No
# NaN            3                        I code primarily as a hobby      Yes
# 25.0           4                     I am a developer by profession      Yes
# 31.0           5  I used to be a developer by profession, but no...      Yes
# ...          ...                                                ...      ...
# NaN        64858                                                NaN      Yes
# NaN        64867                                                NaN      Yes
# NaN        64898                                                NaN      Yes
# NaN        64925                                                NaN      Yes
# NaN        65112                                                NaN      Yes
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=64461, step=1)

# %%
df.set_index("Age", inplace=True)

# %%
df.index
# Out:
# Float64Index([ nan,  nan,  nan, 25.0, 31.0,  nan,  nan, 36.0, 30.0, 22.0,
#               ...
#                nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan],
#              dtype='float64', name='Age', length=64461)

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#     Age  Respondent                                         MainBranch  \
# 0   NaN           1                     I am a developer by profession
# 1   NaN           2                     I am a developer by profession
# 2   NaN           3                        I code primarily as a hobby
# 3  25.0           4                     I am a developer by profession
# 4  31.0           5  I used to be a developer by profession, but no...
#
#   Hobbyist Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0      Yes         13  Monthly        NaN            NaN             Germany
# 1       No         19      NaN        NaN            NaN      United Kingdom
# 2      Yes         15      NaN        NaN            NaN  Russian Federation
# 3      Yes         18      NaN        NaN            NaN             Albania
# 4      Yes         16      NaN        NaN            NaN       United States
#
# ...

# %%
df = pd.read_csv("data/survey_results_public.csv", index_col="Respondent")

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...
